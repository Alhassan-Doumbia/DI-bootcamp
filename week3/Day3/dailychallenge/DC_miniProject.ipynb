# %% [markdown]
# ## Importation des modules pythons

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analyse exploratoire

# %%
df=pd.read_csv('MOBILE_PRICES.csv')
df.head(10)

#J'ai besoin de la  liste des colonnes , des types de colonnes ,
print("="*30)
#les types de données de chaque data 
data_columns=df.columns
for column in data_columns:
    print("-"*30)
    print(f"Le type de données de la colonne '{column}' est : {df[column].dtype}")

#statistique descriptive 
print("="*30)
print("Information sur le dataset :")
print(df.info())
# Out:
# ...
# ------------------------------
# Le type de données de la colonne 'battery_power' est : int64
# ------------------------------
# Le type de données de la colonne 'blue' est : int64
# ------------------------------
# Le type de données de la colonne 'clock_speed' est : float64
# ------------------------------
# Le type de données de la colonne 'dual_sim' est : int64
# ------------------------------
# Le type de données de la colonne 'fc' est : int64
# ------------------------------
# Le type de données de la colonne 'four_g' est : int64
# ------------------------------
# Le type de données de la colonne 'int_memory' est : int64
# ------------------------------
# Le type de données de la colonne 'm_dep' est : float64
# ------------------------------
# Le type de données de la colonne 'mobile_wt' est : int64
# ------------------------------
# Le type de données de la colonne 'n_cores' est : int64
# ------------------------------
# Le type de données de la colonne 'pc' est : int64
# ...

# %%
# Calcul des valeurs centrales 
print("="*30)
print("statistique descriptive :")
print(df.describe())
# Out:
# ...
# statistique descriptive :
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# ...

# %%
#Nettoyage des données 

df_missing_values=df.isnull().sum()
if(df_missing_values.any()):
    print("-------------------------------")
    print(df.isnull().sum())
    print("Il y a des valeurs manquantes dans les données.")
else:
    print("il n'ya pas de valeur manquante dans ce dataset")

# selon le résultat nous allons traiter les données 
# Selon le résultat , il n'ya pas de données manquante dans notre dataset , nous alons maintenant voir pour les variables qui nous intéressent particulièrement si'il ya des valeurs aberrante
# Out:
# il n'ya pas de valeur manquante dans ce dataset
