# %%
from faker import Faker
fake = Faker('EN')
print(fake.name())          # Ex: 'Jean Dupont'
print(fake.job())           # Ex: 'Ingénieur logiciel'
print(fake.company())       # Ex: 'Tech Solutions SAS'
print(fake.profile())       # Retourne un dictionnaire complet (nom, emploi, email, etc.)
# Out:
# William Cantrell
# Police officer
# Gross, Richardson and Johnson
# {'job': 'Conference centre manager', 'company': 'Vasquez-Sullivan', 'ssn': '790-34-0998', 'residence': '70833 Lynn Unions Suite 128\nZacharyhaven, NY 03521', 'current_location': (Decimal('-7.2720925'), Decimal('48.451611')), 'blood_group': 'A-', 'website': ['https://bates-reyes.com/', 'https://pruitt-johnson.com/', 'http://serrano.com/'], 'username': 'diazrandy', 'name': 'Melinda Martinez', 'sex': 'F', 'address': '615 Laura Cliff\nEast Dale, MP 86910', 'mail': 'gthompson@gmail.com', 'birthdate': datetime.date(2001, 3, 25)}

# %%
interest=list(fake.words())
print(interest)
# Out:
# ['or', 'method', 'such']

# %%
import numpy as np
import random
interests_pool = [
    "technology",
    "programming",
    "artificial intelligence",
    "cybersecurity",
    "robotics",
    "gaming",
    "video games",
    "music",
    "singing",
    "playing guitar",
    "playing piano",
    "podcasts",
    "radio",
    "sports",
    "football",
    "basketball",
    "tennis",
    "running",
    "fitness",
    "bodybuilding",
    "yoga",
    "swimming",
    "cycling",
    "hiking",
    "martial arts",
    "cooking",
    "baking",
    "coffee",
    "wine tasting",
    "travel",
    "backpacking",
    "camping",
    "road trips",
    "cinema",
    "movies",
    "television series",
    "anime",
    "documentaries",
    "photography",
    "videography",
    "drawing",
    "painting",
    "graphic design",
    "fashion",
    "beauty",
    "interior design",
    "architecture",
    "reading",
    "writing",
    "poetry",
    "blogging",
    "journalism",
    "history",
    "geography",
    "philosophy",
    "psychology",
    "science",
    "astronomy",
    "physics",
    "biology",
    "chemistry",
    "mathematics",
    "economics",
    "finance",
    "investing",
    "cryptocurrency",
    "entrepreneurship",
    "marketing",
    "business",
    "languages",
    "learning languages",
    "education",
    "public speaking",
    "networking",
    "volunteering",
    "charity work",
    "politics",
    "environment",
    "sustainability",
    "gardening",
    "pets",
    "dogs",
    "cats",
    "bird watching",
    "fishing",
    "hunting",
    "cars",
    "motorcycles",
    "aviation",
    "space exploration",
    "collecting",
    "board games",
    "chess",
    "puzzles",
    "magic tricks",
    "dance",
    "theater",
    "comedy",
    "meditation",
    "personal development",
    "self-improvement",
    "productivity",
    "mindfulness",
    "luxury lifestyle",
    "social media",
    "content creation",
    "streaming",
    "esports"
]
# interests = np.random.choice(interests_pool,random.randint(2,6))

#debug
for i in range(1,10):
    print(f'---{i}---')
    interests = np.random.choice(interests_pool,random.randint(2,6))
    print(interests)
    print(f"----Taille du tableau {len(interests)}")
# Out:
# ---1---
# ['productivity' 'hunting' 'economics' 'puzzles' 'physics']
# ----Taille du tableau 5
# ---2---
# ['volunteering' 'aviation']
# ----Taille du tableau 2
# ---3---
# ['chemistry' 'cinema']
# ----Taille du tableau 2
# ---4---
# ['playing guitar' 'marketing' 'interior design']
# ----Taille du tableau 3
# ---5---
# ['mathematics' 'mindfulness']
# ----Taille du tableau 2
# ---6---
# ['videography' 'travel' 'charity work' 'cars' 'collecting']
# ----Taille du tableau 5
# ---7---
# ['history' 'playing guitar' 'interior design' 'wine tasting'
#  'bodybuilding' 'hiking']
# ----Taille du tableau 6
# ---8---
# ['personal development' 'marketing' 'reading' 'cybersecurity' 'comedy'
#  'self-improvement']
# ----Taille du tableau 6
# ---9---
# ['programming' 'bodybuilding' 'robotics']
# ----Taille du tableau 3

# %%
from faker import Faker
import random
import json
import numpy as np
import pandas as pd
fake = Faker('EN') # Pour des données en français

def generate_user_profile():
    interests_pool = [
    "technology",
    "programming",
    "artificial intelligence",
    "cybersecurity",
    "robotics",
    "gaming",
    "video games",
    "music",
    "singing",
    "playing guitar",
    "playing piano",
    "podcasts",
    "radio",
    "sports",
    "football",
    "basketball",
    "tennis",
    "running",
    "fitness",
    "bodybuilding",
    "yoga",
    "swimming",
    "cycling",
    "hiking",
    "martial arts",
    "cooking",
    "baking",
    "coffee",
    "wine tasting",
    "travel",
    "backpacking",
    "camping",
    "road trips",
    "cinema",
    "movies",
    "television series",
    "anime",
    "documentaries",
    "photography",
    "videography",
    "drawing",
    "painting",
    "graphic design",
    "fashion",
    "beauty",
    "interior design",
    "architecture",
    "reading",
    "writing",
    "poetry",
    "blogging",
    "journalism",
    "history",
    "geography",
    "philosophy",
    "psychology",
    "science",
    "astronomy",
    "physics",
    "biology",
    "chemistry",
    "mathematics",
    "economics",
    "finance",
    "investing",
    "cryptocurrency",
    "entrepreneurship",
    "marketing",
    "business",
    "languages",
    "learning languages",
    "education",
    "public speaking",
    "networking",
    "volunteering",
    "charity work",
    "politics",
    "environment",
    "sustainability",
    "gardening",
    "pets",
    "dogs",
    "cats",
    "bird watching",
    "fishing",
    "hunting",
    "cars",
    "motorcycles",
    "aviation",
    "space exploration",
    "collecting",
    "board games",
    "chess",
    "puzzles",
    "magic tricks",
    "dance",
    "theater",
    "comedy",
    "meditation",
    "personal development",
    "self-improvement",
    "productivity",
    "mindfulness",
    "luxury lifestyle",
    "social media",
    "content creation",
    "streaming",
    "esports"
]
    actions = ["watched", "listened to", "bought", "read about", "shared"]
    topics = [
    "AI talk",
    "machine learning trends",
    "deep learning",
    "generative AI",
    "robotics news",
    "cybersecurity tips",
    "programming languages",
    "web development",
    "mobile apps",
    "cloud computing",
    "startup ideas",
    "entrepreneurship",
    "product management",
    "digital marketing",
    "stock market",
    "personal finance",
    "cryptocurrency",
    "economic trends",

    "rock music",
    "jazz album",
    "classical music",
    "hip hop culture",
    "electronic music",
    "indie bands",
    "music festivals",
    "vinyl records",
    "concert experiences",
    "guitar techniques",
    "piano practice",
    "music production",
    "podcast recommendations",

    "headphones",
    "wireless earbuds",
    "audio equipment",
    "mechanical keyboards",
    "gaming setup",
    "smartphones",
    "laptops",
    "smartwatches",
    "camera gear",
    "drones",
    "electric vehicles",
    "home automation",

    "sci-fi book",
    "fantasy novels",
    "historical fiction",
    "mystery stories",
    "book recommendations",
    "creative writing",
    "poetry",
    "journalism",
    "philosophy books",
    "psychology research",

    "running shoes",
    "marathon training",
    "football tactics",
    "basketball highlights",
    "tennis tournaments",
    "cycling routes",
    "fitness routines",
    "strength training",
    "yoga practice",
    "swimming techniques",
    "hiking adventures",
    "outdoor survival",

    "travel destinations",
    "road trip ideas",
    "backpacking tips",
    "luxury hotels",
    "local cuisine",
    "street food",
    "coffee culture",
    "wine tasting",
    "cooking recipes",
    "healthy eating",

    "movie reviews",
    "cinema classics",
    "tv series",
    "anime discussion",
    "documentaries",
    "photography techniques",
    "video editing",
    "graphic design",
    "fashion trends",
    "interior design",

    "space exploration",
    "astronomy discoveries",
    "physics concepts",
    "biology news",
    "climate change",
    "renewable energy",
    "environmental issues",
    "scientific breakthroughs",

    "history podcasts",
    "ancient civilizations",
    "world politics",
    "international relations",
    "cultural traditions",
    "language learning",
    "education technology",

    "board games",
    "chess strategy",
    "video game releases",
    "esports tournaments",
    "virtual reality",
    "collectible cards",
    "puzzle solving",

    "meditation",
    "mindfulness",
    "personal development",
    "productivity hacks",
    "career growth",
    "leadership skills",
    "networking events",
    "remote work",
    "work-life balance"
]

    # Génération des intérêts (2 à 6 éléments)
    # Convertir le numpy array en liste avec .tolist()
    interests = np.random.choice(interests_pool, random.randint(2,6)).tolist()

    # Génération d'un log d'activité (3 à 6 actions)
    activity_log = [
        f"{np.random.choice(actions).tolist()} {np.random.choice(topics).tolist()}" 
        for _ in range(random.randint(3,6))
    ]

    return {
        "name": fake.name(),
        "age": fake.random_int(min=18, max=60),
        "interests": interests,
        "activity_log": activity_log
    }

# Générer 5 exemples
dataset = [generate_user_profile() for _ in range(5)]

# dataset=[]
# for element in range(10):
#     dataset.append(generate_user_profile())


# print(json.dumps(dataset, indent=4))  
dataset=pd.DataFrame(data=dataset)
dataset.to_json("./data.json",orient="records",indent=4)

dataset
# user_dataframe
# Out:
#              name  age                                          interests  \
# 0  Tracey Shields   21                   [technology, podcasts, aviation]
# 1    Kathy Melton   24  [politics, gaming, collecting, board games, ba...
# 2   William Jones   42  [space exploration, anime, road trips, educati...
# 3   Daniel Taylor   48                              [marketing, politics]
# 4     Kevin Wyatt   53                         [blogging, cryptocurrency]
#
#                                         activity_log
# 0  [shared healthy eating, listened to jazz album...
# 1  [bought local cuisine, listened to generative ...
# 2  [watched fashion trends, watched video editing...
# 3  [watched entrepreneurship, shared marathon tra...
# 4  [read about startup ideas, listened to mechani...

# %%
import random
import numpy as np 

actions = ["watched", "listened to", "bought", "read about", "shared"]
topics={
        'technology':[
            "AI talk",
            "machine learning trends",
            "deep learning",
            "generative AI",
            "robotics news",
            "cybersecurity tips",
            "programming languages",
            "web development"
    ],
        'music':[ 
            "rock music",
            "jazz album",
            "classical music",
            "hip hop culture",
            "electronic music",
            "indie bands",
            "music festivals"
    ],
        'electronics': [  
            "headphones",
            "wireless earbuds",
            "audio equipment",
            "mechanical keyboards",
            "gaming setup",
            "smartphones",
            "laptops"
    ],

        'wellbeing':[
            "meditation",
            "mindfulness",
            "personal development",
            "productivity hacks",
            "career growth",
            "leadership skills",

    ],

}

interests_pool=["technology","wellbeing",'electronics','music']

class User:
    def __init__(self,name):
        self.name=name
    def define_activity_log(self):
        activity_log=[]
        for element in range(random.randint(3,6)):
            interests =np.random.choice(interests_pool,np.random.randint(2,6)).tolist()
            for interest in interests:
                activity_log.append(f"{random.choice(actions)} {random.choice(topics[interest])}")
        return activity_log

    

user_1=User("john")
activity_log=user_1.define_activity_log()
print(activity_log)
# Out:
# ['bought electronic music', 'watched rock music', 'shared hip hop culture', 'bought mindfulness', 'listened to personal development', 'read about hip hop culture', 'listened to cybersecurity tips', 'shared personal development', 'bought productivity hacks', 'shared wireless earbuds', 'bought audio equipment', 'listened to classical music', 'listened to gaming setup']

# %%
from faker import Faker
import random
import json
import numpy as np
import pandas as pd
fake = Faker('EN') # Pour des données en anglais

actions = ["watched", "listened to", "bought", "read about", "shared"]
topics={
            'technology':[
                "AI talk",
                "machine learning trends",
                "deep learning",
                "generative AI",
                "robotics news",
                "cybersecurity tips",
                "programming languages",
                "web development"
        ],
            'music':[ 
                "rock music",
                "jazz album",
                "classical music",
                "hip hop culture",
                "electronic music",
                "indie bands",
                "music festivals"
        ],
            'electronics': [  
                "headphones",
                "wireless earbuds",
                "audio equipment",
                "mechanical keyboards",
                "gaming setup",
                "smartphones",
                "laptops"
        ],

            'wellbeing':[
                "meditation",
                "mindfulness",
                "personal development",
                "productivity hacks",
                "career growth",
                "leadership skills",

        ],

}
interests_pool=["technology","wellbeing",'electronics','music']
def create_activity_log(action,topic): #topic signifie l'un des intérêts enfait 
        return f"{action} {random.choice(topics[topic])}"

def generate_user_profiles_dataset():
        user_interests = np.random.choice(interests_pool, random.randint(2,5)).tolist()
        activity_log=[]
        # for interest in user_interests():
        #         activity_log.append(create_activity_log(random.choice(actions),interest))
        for e in range(random.randint(2,5)):
                activity_log.append(create_activity_log(random.choice(actions), random.choice(user_interests)))

        #         #debug
        # return activity_log
        return {
                "name":fake.name(),
                "age": fake.random_int(min=18, max=60),
                "interests": user_interests,
                "activity_log": activity_log
        }

generate_user_profiles_dataset() #this new  algorithm gives better dataset because now the interests is really corellated to the activity logo
# Out:
# {'name': 'Martin Thomas',
#  'age': 52,
#  'interests': ['wellbeing', 'music'],
#  'activity_log': ['watched mindfulness',
#   'read about meditation',
#   'listened to rock music',
#   'shared classical music',
#   'shared indie bands']}

# %%
from faker import Faker
import random
import json
import numpy as np
import pandas as pd
def generate_user_profile():
    fake = Faker('EN') # Pour des données en anglais
    interests_pool = [
    "technology",
    "programming",
    "artificial intelligence",
    "cybersecurity",
    "robotics",
    "gaming",
    "video games",
    "music",
    "singing",
    "playing guitar",
    "playing piano",
    "podcasts",
    "radio",
    "sports",
    "football",
    "basketball",
    "tennis",
    "running",
    "fitness",
    "bodybuilding",
    "yoga",
    "swimming",
    "cycling",
    "hiking",
    "martial arts",
    "cooking",
    "baking",
    "coffee",
    "wine tasting",
    "travel",
    "backpacking",
    "camping",
    "road trips",
    "cinema",
    "movies",
    "television series",
    "anime",
    "documentaries",
    "photography",
    "videography",
    "drawing",
    "painting",
    "graphic design",
    "fashion",
    "beauty",
    "interior design",
    "architecture",
    "reading",
    "writing",
    "poetry",
    "blogging",
    "journalism",
    "history",
    "geography",
    "philosophy",
    "psychology",
    "science",
    "astronomy",
    "physics",
    "biology",
    "chemistry",
    "mathematics",
    "economics",
    "finance",
    "investing",
    "cryptocurrency",
    "entrepreneurship",
    "marketing",
    "business",
    "languages",
    "learning languages",
    "education",
    "public speaking",
    "networking",
    "volunteering",
    "charity work",
    "politics",
    "environment",
    "sustainability",
    "gardening",
    "pets",
    "dogs",
    "cats",
    "bird watching",
    "fishing",
    "hunting",
    "cars",
    "motorcycles",
    "aviation",
    "space exploration",
    "collecting",
    "board games",
    "chess",
    "puzzles",
    "magic tricks",
    "dance",
    "theater",
    "comedy",
    "meditation",
    "personal development",
    "self-improvement",
    "productivity",
    "mindfulness",
    "luxury lifestyle",
    "social media",
    "content creation",
    "streaming",
    "esports"
]
    actions = ["watched", "listened to", "bought", "read about", "shared"]
    topics = [
    "AI talk",
    "machine learning trends",
    "deep learning",
    "generative AI",
    "robotics news",
    "cybersecurity tips",
    "programming languages",
    "web development",
    "mobile apps",
    "cloud computing",
    "startup ideas",
    "entrepreneurship",
    "product management",
    "digital marketing",
    "stock market",
    "personal finance",
    "cryptocurrency",
    "economic trends",

    "rock music",
    "jazz album",
    "classical music",
    "hip hop culture",
    "electronic music",
    "indie bands",
    "music festivals",
    "vinyl records",
    "concert experiences",
    "guitar techniques",
    "piano practice",
    "music production",
    "podcast recommendations",

    "headphones",
    "wireless earbuds",
    "audio equipment",
    "mechanical keyboards",
    "gaming setup",
    "smartphones",
    "laptops",
    "smartwatches",
    "camera gear",
    "drones",
    "electric vehicles",
    "home automation",

    "sci-fi book",
    "fantasy novels",
    "historical fiction",
    "mystery stories",
    "book recommendations",
    "creative writing",
    "poetry",
    "journalism",
    "philosophy books",
    "psychology research",

    "running shoes",
    "marathon training",
    "football tactics",
    "basketball highlights",
    "tennis tournaments",
    "cycling routes",
    "fitness routines",
    "strength training",
    "yoga practice",
    "swimming techniques",
    "hiking adventures",
    "outdoor survival",

    "travel destinations",
    "road trip ideas",
    "backpacking tips",
    "luxury hotels",
    "local cuisine",
    "street food",
    "coffee culture",
    "wine tasting",
    "cooking recipes",
    "healthy eating",

    "movie reviews",
    "cinema classics",
    "tv series",
    "anime discussion",
    "documentaries",
    "photography techniques",
    "video editing",
    "graphic design",
    "fashion trends",
    "interior design",

    "space exploration",
    "astronomy discoveries",
    "physics concepts",
    "biology news",
    "climate change",
    "renewable energy",
    "environmental issues",
    "scientific breakthroughs",

    "history podcasts",
    "ancient civilizations",
    "world politics",
    "international relations",
    "cultural traditions",
    "language learning",
    "education technology",

    "board games",
    "chess strategy",
    "video game releases",
    "esports tournaments",
    "virtual reality",
    "collectible cards",
    "puzzle solving",

    "meditation",
    "mindfulness",
    "personal development",
    "productivity hacks",
    "career growth",
    "leadership skills",
    "networking events",
    "remote work",
    "work-life balance"
]

    # Génération des intérêts (2 à 6 éléments)
    # Convertir le numpy array en liste avec .tolist()
    interests = np.random.choice(interests_pool, random.randint(2,6)).tolist()

    # Génération d'un log d'activité (3 à 6 actions)
    activity_log = [
        f"{np.random.choice(actions)} {np.random.choice(topics)}" 
        for _ in range(random.randint(3,6))
    ]

    return {
        "name": fake.name(),
        "age": fake.random_int(min=18, max=60),
        "interests": interests,
        "activity_log": activity_log
    }

generate_user_profile()
# Out:
# {'name': 'Benjamin Chandler',
#  'age': 36,
#  'interests': ['charity work',
#   'movies',
#   'playing piano',
#   'personal development'],
#  'activity_log': ['listened to jazz album',
#   'watched cinema classics',
#   'read about esports tournaments',
#   'bought swimming techniques',
#   'listened to history podcasts',
#   'bought road trip ideas']}
